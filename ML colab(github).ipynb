# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiram54369/ml-projects-and-assignments/blob/main/ML%20colab(github).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
